# %% [markdown]
# **CHAPTER 1 EXERCISES**

# %% [markdown]
# Exercise 1
#
# Each line of code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
print('Hello world!') #the letter p in the word print is in capital letter
# Out:
# Hello world!

# %%
print('Hello world!') #the opening parethesis is missing
# Out:
# Hello world!

# %%
print('Hello world!') #the closing single quote is missing
# Out:
# Hello world!

# %%
print('Hello world!') #the closing single quote is doubled
# Out:
# Hello world!

# %% [markdown]
# Exercise 2
#
# What is the output of the code below?

# %%
x = 43
x = x + 1
print(x) #the output of the code is 44
# Out:
# 44

# %% [markdown]
# Exercise 3
#
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = x + 1 #the object x in the formula is in capital letter
print(x)
# Out:
# 44
