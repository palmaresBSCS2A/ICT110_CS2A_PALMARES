# %% [markdown]
# **CHAPTER 5 EXERCISES**

# %% [markdown]
# **Exercise 1**
#
# Investigate on the difference between is and == given the following variables.
#
# a = 2
# b = 2.0
# c = a

# %%
a = 2
b = 2.0
c = a

print (a == b) #True because the values are equal
print (a is b) #False because a and b are different objects w/ different types
print (a == c) #True because the values are equal
print (a is c) #True because they a and c refer to the same object inside the cell
print (b == c) #True because the values are equal
print (b is c) #False because b and c are different objects w/ different types
# Out:
# True
# False
# True
# True
# True
# False

# %% [markdown]
# **Challenge 1**
#
# Write a program which repeatedly reads numbers until the user enters "done". Once "done" is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.
#
# Enter a number: 4
# Enter a number: 5
# Enter a number: bad data
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16 3 5.333333333333333

# %%
total = 0
count = 0

while True :
  num = input('Enter a number: ')
  if num.lower() == 'done' :
    break

  try :
    number = float(num)
    total = total + number
    count = count + 1
  except ValueError :
    print ('Invalid input')

  if count > 0 :
    average = total/ count
    print('Total: ', total, '\nCount: ', count, '\nAverage: ', average)
  else :
    print ('Please enter a valid number')
# Out:
# Enter a number: 4
# Total:  4.0
# Count:  1
# Average:  4.0
# Enter a number: 5
# Total:  9.0
# Count:  2
# Average:  4.5
# Enter a number: bad data
# Invalid input
# Total:  9.0
# Count:  2
# Average:  4.5
# Enter a number: 7
# Total:  16.0
# Count:  3
# Average:  5.333333333333333
# Enter a number: done

# %% [markdown]
# **Challenge 2**
#
# Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.
#
# Enter a numer: 5
# Maximum :  5.0
# Minimum:  5.0
# Enter a numer: 5 12
# Invalid input
# Maximum :  5.0
# Minimum:  5.0
# Enter a numer: 2
# Maximum :  5.0
# Minimum:  2.0
# Enter a numer: 4
# Maximum :  5.0
# Minimum:  2.0
# Enter a numer: 9
# Maximum :  9.0
# Minimum:  2.0
# Enter a numer: 0
# Maximum :  9.0
# Minimum:  0.0
# Enter a numer: -1
# Maximum :  9.0
# Minimum:  -1.0
# Enter a numer: done

# %%
max_num = None
min_num = None

while True :
  num = input('Enter a number: ')
  if num.lower() == 'done' :
    break

  try :
    number = float(num)

    if max_num is None or number > max_num :
      max_num = number

    if min_num is None or number < min_num :
      min_num = number

  except ValueError :
    print ('Invalid input')

  if max_num is not None and min_num is not None :
    print('Maximum : ', max_num, '\nMinimum: ', min_num)
  else :
    print ('Please enter valid numbers.')
# Out:
# Enter a number: 5
# Maximum :  5.0
# Minimum:  5.0
# Enter a number: 5 12
# Invalid input
# Maximum :  5.0
# Minimum:  5.0
# Enter a number: 2
# Maximum :  5.0
# Minimum:  2.0
# Enter a number: 4
# Maximum :  5.0
# Minimum:  2.0
# Enter a number: 9
# Maximum :  9.0
# Minimum:  2.0
# Enter a number: 0
# Maximum :  9.0
# Minimum:  0.0
# Enter a number: -1
# Maximum :  9.0
# Minimum:  -1.0
