# %% [markdown]
# **CHAPTER 6 EXERCISES**

# %% [markdown]
# **Exercise 1**
#
# Given the code below
#
#     text = 'Business Analytics'
#
# What will the following expressions produce?
#
#     text[4]
#     text[2:4]
#     text[:4]
#     text[4:]
#     text[-2]
#     text[-4:-2]
#     text[-2:]
#     text[:-2]

# %%
text = 'Business Analytics'
text[4]  # 'n'
text[2:4] # 'si'
text[:4] # 'Busi'
text[4:] # 'ness Analytics'
text[-2] # 'c'
text[-4:-2] # 'ti'
text[-2:] # 'cs'
text[:-2] # 'Business Analyti'
# Out:
# 'Business Analyti'

# %% [markdown]
# **Exercise 2**

# %%
phrase = 'One Ring to rule them all'
'all'
'them'
'One Ring to rule them all'
'One '
'Ring'
'all'
'them'
'Rule'
# Out:
# 'Rule'

# %% [markdown]
# **Challenge**

# %% [markdown]
# Write a program which repeatedly reads a **full name**, then does the following:
# - strips the name of any trailing spaces
# - capitalizes the first letter
# - puts the rest into smaller letters

# %%
while True:
    fullName = input("Enter a full name (or type 'exit'): ")

    if fullName.lower() == 'exit':
        break

    formattedName = fullName.strip().capitalize()

    print("Formatted Name:", formattedName)
# Out:
# Enter a full name (or type 'exit'): mary angel palmares
# Formatted Name: Mary angel palmares
# Enter a full name (or type 'exit'): MARY ANGEL PALMARES
# Formatted Name: Mary angel palmares
# Enter a full name (or type 'exit'): mary Angel Palmares
# Formatted Name: Mary angel palmares
# Enter a full name (or type 'exit'): exit
