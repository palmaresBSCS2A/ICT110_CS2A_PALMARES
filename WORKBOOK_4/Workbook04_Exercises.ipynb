# %% [markdown]
# #### Exercise 1
# Adapted from [TCS] Appendix D, Exercise 2
#
# Open help for the math module.
#
# - What are the constants in the math module?
# - What's does `math.exp` do? What about `math.pow`?
# - How do you calculate logarithms? Logarithms base 10? Natural Logarithms?

# %% [markdown]
# #1. the following are the constants found in the math module
#     e = 2.718281828459045
#     inf = inf
#     nan = nan
#     pi = 3.141592653589793
#     tau = 6.283185307179586
#
# #2.
# exp(x, /) - math.exp calculates e raised to the power of x
#         Return e raised to the power of x.
#
#
# pow(x, y, /) - math.pow alculates x raised to the power of y
#         Return x**y (x to the power of y).
#
# #3.
# log(x, [base=math.e]) - math.log(x, [base]) calculates the logarithm of x to the given base.
#         Return the logarithm of x to the given base.
#
#
# log10(x, /) - math.log10(x) calculates the base 10 logarithm of x.
#         Return the base 10 logarithm of x.
#
#
# log1p(x, /) - math.log(x) calculates the natural logarithm (base e) of x.
#         Return the natural logarithm of 1+x (base e).

# %% [markdown]
# #### Exercise 2
# - Create your own module.
# - Place variables and functions inside it.
# - Import your module and use the variabls and functions you've created in the module.
# - Try to add docstrings for the module and the functions
#
# [あ]

# %%
# %%writefile capiz.py

"""
This module provides functions related to Capiz town names and their postal codes.
"""

capiz_dict = {
    'Ivisan': 5805,
    'Roxas City': 5800,
    'Dumarao': 5812,
    'Sapian': 5806,
    'Tapaz': 5814
}

def postal_code(place_name):
    """
    Retrieve the postal code for a given place name from the capiz_dict dictionary.

    Parameters: the name of the place for which to retrieve the postal code.

    Returns: the postal code of the place if found in the dictionary, otherwise returns None.
    """
    return capiz_dict.get(place_name)
# Out:
# Writing capiz.py

# %%
import capiz

# %%
place = input('Enter Town in Capiz: ')
code = capiz.postal_code(place)
print(f"Postal Code of {place} is {code}.")
# Out:
# Enter Town in Capiz: Ivisan
# Postal Code of Ivisan is 5805.

# %%
help(capiz)
# Out:
# Help on module capiz:
#
# NAME
#     capiz - This module provides functions related to Capiz town names and their postal codes.
#
# FUNCTIONS
#     postal_code(place_name)
#         Retrieve the postal code for a given place name from the capiz_dict dictionary.
#
#         Parameters: the name of the place for which to retrieve the postal code.
#
#         Returns: the postal code of the place if found in the dictionary, otherwise returns None.
#
# DATA
#     capiz_dict = {'Dumarao': 5812, 'Ivisan': 5805, 'Roxas City': 5800, 'Sa...
#
# FILE
#     /content/capiz.py
